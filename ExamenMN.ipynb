# %%
def secant_method(f, x0, x1, tol=1e-6, max_iter=100):
    
    x_prev = x0
    x_curr = x1
    iter_count = 0

    while abs((x_curr-x_prev)/x_curr) > tol and iter_count < max_iter:
        x_next = x_curr - f(x_curr) * (x_curr - x_prev) / (f(x_curr) - f(x_prev))
        global i
        i += 1
        x_prev = x_curr
        x_curr = x_next
        iter_count += 1
        print(f"Llamada i={i}\t x={x_curr:.5f}\t y={f(x_curr):.2f}")

    return x_curr, iter_count

i = 0


def func(x):
    y = x**5+(x**4)*5.25+(x**3)*4.125-(x**2)*9.125-x*5.625
    return y


secant_method(func, x0=2, x1=3)
# Out:
# Llamada i=1	 x=1.82524	 y=62.94
# Llamada i=2	 x=1.70553	 y=43.18
# Llamada i=3	 x=1.44397	 y=14.37
# Llamada i=4	 x=1.31348	 y=5.75
# Llamada i=5	 x=1.22641	 y=1.64
# Llamada i=6	 x=1.19177	 y=0.31
# Llamada i=7	 x=1.18357	 y=0.02
# Llamada i=8	 x=1.18289	 y=0.00
# Llamada i=9	 x=1.18288	 y=0.00
# Llamada i=10	 x=1.18288	 y=0.00
# (1.1828817939773408, 10)

# %%
def secant_method(f, x0, x1, tol=1e-6, max_iter=100):
    
    x_prev = x0
    x_curr = x1
    iter_count = 0

    while abs((x_curr-x_prev)/x_curr) > tol and iter_count < max_iter:
        x_next = x_curr - f(x_curr) * (x_curr - x_prev) / (f(x_curr) - f(x_prev))
        global i
        i += 1
        x_prev = x_curr
        x_curr = x_next
        iter_count += 1
        print(f"Llamada i={i}\t x={x_curr:.5f}\t y={f(x_curr):.2f}")

    return x_curr, iter_count

i = 0


def func(x):
    y = x**3 +2 * x**2 + 3 * x - 1
    return y


secant_method(func, x0=2, x1=3)
# Out:
# Llamada i=1	 x=1.34375	 y=9.07
# Llamada i=2	 x=1.00184	 y=5.02
# Llamada i=3	 x=0.57823	 y=1.60
# Llamada i=4	 x=0.38055	 y=0.49
# Llamada i=5	 x=0.29395	 y=0.08
# Llamada i=6	 x=0.27689	 y=0.01
# Llamada i=7	 x=0.27570	 y=0.00
# Llamada i=8	 x=0.27568	 y=0.00
# Llamada i=9	 x=0.27568	 y=0.00
# (0.2756822036510897, 9)

# %%
def secant_method(f, x0, x1, tol=1e-6, max_iter=100):

    x_prev = x0
    x_curr = x1
    iter_count = 0

    while abs((x_curr-x_prev)/x_curr) > tol and iter_count < max_iter:
        x_next = x_curr - f(x_curr) * (x_curr - x_prev) / (f(x_curr) - f(x_prev))
        global i
        i += 1
        x_prev = x_curr
        x_curr = x_next
        iter_count += 1
        print(f"Llamada i={i}\t x={x_curr:.5f}\t y={f(x_curr):.2f}")

    return x_curr, iter_count

i = 0


def func(x):
    y = 35*np.sin(x/np.pi)+10
    return y


secant_method(func, x0=2, x1=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 26
#      22     y = 35*np.sin(x/np.pi)+10
#      23     return y
#      24
#      25
# ---> 26 secant_method(func, x0=2, x1=3)
#
# Cell In[9], line 8, in secant_method(f, x0, x1, tol, max_iter)
#       4     x_curr = x1
#       5     iter_count = 0
#       6
#       7     while abs((x_curr-x_prev)/x_curr) > tol and iter_count < max_iter:
# ----> 8         x_next = x_curr - f(x_curr) * (x_curr - x_prev) / (f(x_curr) - f(x_prev))
#       9         global i
#      10         i += 1
#      11         x_prev = x_curr
#
# Cell In[9], line 22, in func(x)
#      21 def func(x):
# ---> 22     y = 35*np.sin(x/np.pi)+10
#      23     return y
#
# NameError: name 'np' is not defined
